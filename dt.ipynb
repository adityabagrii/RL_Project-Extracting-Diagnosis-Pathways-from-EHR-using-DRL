# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, roc_auc_score

# Load datasets
train_data = pd.read_csv("data/train_set_basic.csv")
test_data = pd.read_csv("data/test_set_constant.csv")

# Inspect the columns in the dataset
print("Train Data Columns:", train_data.columns)
print("Test Data Columns:", test_data.columns)

# Adjust feature columns based on the actual columns in your dataset
feature_columns = [
    'hemoglobin', 'ferritin', 'ret_count', 'segmented_neutrophils', 'tibc',
    'mcv', 'serum_iron', 'rbc', 'gender', 'creatinine', 'cholestrol',
    'copper', 'ethanol', 'folate', 'glucose', 'hematocrit', 'tsat'
]
target_column = 'label'

# Ensure all feature columns exist in the dataset
missing_columns = [col for col in feature_columns if col not in train_data.columns]
if missing_columns:
    print(f"Missing columns in train data: {missing_columns}")
else:
    # Split train and test data
    X_train = train_data[feature_columns]
    y_train = train_data[target_column]

    X_test = test_data[feature_columns]
    y_test = test_data[target_column]

    # Initialize Decision Tree Classifier
    dt_model = DecisionTreeClassifier(criterion="gini", max_depth=5, random_state=42)

    # Train the model
    dt_model.fit(X_train, y_train)

    # Predictions
    y_pred = dt_model.predict(X_test)
    y_pred_proba = dt_model.predict_proba(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')

    print("Accuracy:", accuracy)
    print("F1 Score:", f1)
    print("ROC AUC Score:", roc_auc)
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

    # Export Decision Tree
    tree_rules = export_text(dt_model, feature_names=feature_columns)
    print("\nDecision Tree Rules:\n", tree_rules)
# Out:
# Train Data Columns: Index(['hemoglobin', 'ferritin', 'ret_count', 'segmented_neutrophils', 'tibc',
#        'mcv', 'serum_iron', 'rbc', 'gender', 'creatinine', 'cholestrol',
#        'copper', 'ethanol', 'folate', 'glucose', 'hematocrit', 'tsat',
#        'label'],
#       dtype='object')
# Test Data Columns: Index(['hemoglobin', 'ferritin', 'ret_count', 'segmented_neutrophils', 'tibc',
#        'mcv', 'serum_iron', 'rbc', 'gender', 'creatinine', 'cholestrol',
#        'copper', 'ethanol', 'folate', 'glucose', 'hematocrit', 'tsat',
#        'label'],
#       dtype='object')
# Accuracy: 0.946
# F1 Score: 0.9460318592403808
# ROC AUC Score: 0.9932387446461056
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91      2000
#            1       1.00      1.00      1.00      1801
#            2       1.00      1.00      1.00      1793
#            3       0.98      0.86      0.92      1772
#            4       0.80      1.00      0.89      1679
#            5       0.96      1.00      0.98      1805
#            6       0.98      1.00      0.99      1806
#            7       0.86      0.87      0.87      1344
#
#     accuracy                           0.95     14000
#    macro avg       0.95      0.95      0.94     14000
# weighted avg       0.95      0.95      0.95     14000
#
#
# Confusion Matrix:
#  [[1657    2    0   28    3   82   39  189]
#  [   0 1801    0    0    0    0    0    0]
#  [   0    0 1793    0    0    0    0    0]
#  [   0    0    0 1530  242    0    0    0]
#  [   0    0    0    0 1679    0    0    0]
#  [   0    0    0    0    0 1805    0    0]
#  [   1    0    0    0    0    0 1805    0]
#  [   0    0    0    0  170    0    0 1174]]
#
# Decision Tree Rules:
#  |--- mcv <= 100.00
# |   |--- hematocrit <= 39.00
# |   |   |--- mcv <= 80.00
# |   |   |   |--- ferritin <= 100.00
# |   |   |   |   |--- ferritin <= -0.49
# |   |   |   |   |   |--- class: 7
# |   |   |   |   |--- ferritin >  -0.49
# |   |   |   |   |   |--- class: 4
# |   |   |   |--- ferritin >  100.00
# |   |   |   |   |--- hematocrit <= 36.00
# |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- hematocrit >  36.00
# |   |   |   |   |   |--- class: 3
# |   |   |--- mcv >  80.00
# |   |   |   |--- ret_count <= 2.10
# |   |   |   |   |--- ret_count <= -0.50
# |   |   |   |   |   |--- class: 7
# |   |   |   |   |--- ret_count >  -0.50
# |   |   |   |   |   |--- class: 6
# |   |   |   |--- ret_count >  2.10
# |   |   |   |   |--- hemoglobin <= 12.00
# |   |   |   |   |   |--- class: 5
# |   |   |   |   |--- hemoglobin >  12.00
# |   |   |   |   |   |--- class: 5
# |   |--- hematocrit >  39.00
# |   |   |--- hematocrit <= 39.00
# |   |   |   |--- glucose <= 49.62
# |   |   |   |   |--- class: 7
# |   |   |   |--- glucose >  49.62
# |   |   |   |   |--- class: 0
# |   |   |--- hematocrit >  39.00
# |   |   |   |--- class: 0
# |--- mcv >  100.00
# |   |--- segmented_neutrophils <= 0.05
# |   |   |--- segmented_neutrophils <= -0.50
# |   |   |   |--- hemoglobin <= 12.99
# |   |   |   |   |--- hemoglobin <= 12.00
# |   |   |   |   |   |--- class: 7
# |   |   |   |   |--- hemoglobin >  12.00
# |   |   |   |   |   |--- class: 7
# |   |   |   |--- hemoglobin >  12.99
# |   |   |   |   |--- class: 0
# |   |   |--- segmented_neutrophils >  -0.50
# |   |   |   |--- class: 2
# |   |--- segmented_neutrophils >  0.05
# |   |   |--- hemoglobin <= 13.02
# |   |   |   |--- hematocrit <= 36.12
# |   |   |   |   |--- class: 1
# |   |   |   |--- hematocrit >  36.12
# |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- hemoglobin >  13.02
# |   |   |   |--- class: 0

# %%
# Give feature importances
importances = dt_model.feature_importances_
print("\nFeature Importances:", importances)
# Out:
# Feature Importances: [2.37579387e-02 1.59060156e-01 2.04948497e-01 2.05444492e-01
#  0.00000000e+00 2.75127891e-01 0.00000000e+00 0.00000000e+00
#  4.52566064e-03 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.52114428e-05 1.27110154e-01
#  0.00000000e+00]
